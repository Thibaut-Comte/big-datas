# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sb

# %%
sp = './datas/sales_predictions.csv'
df = pd.read_csv(sp)

# %%
nuage = sb.relplot(x="date", y="item_price", data=df)

# %% [raw]
# Le chargement est très long. Il y a trop de donnée à traiter.

# %%
nuage = sb.relplot(x="date", y="item_price", data=df.sample(50))

# %%
nuage = sb.relplot(x="date", y="item_price", data=df.sample(50))
nuage.fig.set_figwidth(20)
nuage.fig.set_figheight(6)

# %%
df_bis = df.copy()
df_bis['date'] = pd.to_datetime(df_bis['date'])
nuage = sb.relplot(x="date", y="item_price", data=df_bis.sample(50))
nuage.fig.set_figwidth(20)
nuage.fig.set_figheight(6)
